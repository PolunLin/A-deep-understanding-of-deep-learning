# %% [markdown]
# # COURSE: A deep understanding of deep learning
# ## SECTION: Math prerequisites
# ### LECTURE: Entropy and cross-entropy
# #### TEACHER: Mike X Cohen, sincxpress.com
# ##### COURSE URL: udemy.com/course/dudl/?couponCode=202204

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Reminder of entropy:
#
# $$H(p) = -\sum_x p(x)\log(p(x))$$

# %%
# probability of an event happening
p = .25

# NOT the correct formula!
H = -( p*np.log(p) )
print('Wrong entropy: ' + str(H))
# Out:
# Wrong entropy: 0.34657359027997264

# %%
# the correct way to compute entropy
x = [.25,.75]

H = 0
for p in x:
  H -= p*np.log(p)

print('Correct entropy: ' + str(H))
# Out:
# Correct entropy: 0.5623351446188083

# %%
# also correct, written out for N=2 events
H = -( p*np.log(p) + (1-p)*np.log(1-p) )
print('Correct entropy: ' + str(H))
# Out:
# Correct entropy: 0.5623351446188083

# %% [markdown]
# # Cross-entropy

# %%
# note: all probs must sum to 1!
p = [   1,0   ] # sum=1
q = [ .25,.75 ] # sum=1

H = 0
for i in range(len(p)):
  H -= p[i]*np.log(q[i])

print('Cross entropy: ' + str(H))
# Out:
# Cross entropy: 1.3862943611198906

# %%
# also correct, written out for N=2 events
H = -( p[0]*np.log(q[0]) + p[1]*np.log(q[1]) )
print('Correct entropy: ' + str(H))

# simplification
H = -np.log(q[0])
print('Manually simplified: ' + str(H))
# Out:
# Correct entropy: 1.3862943611198906
# Manually simplified: 1.3862943611198906

# %%
# now using pytorch
import torch
import torch.nn.functional as F

# note: inputs must be Tensors
q_tensor = torch.Tensor(q)
p_tensor = torch.Tensor(p)

F.binary_cross_entropy(p,q)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/polunlin/workspace/A-deep-understanding-of-deep-learning/1.math/6.DUDL_math_entropy.ipynb Cell 20' in <cell line: 9>()
#       <a href='vscode-notebook-cell:/Users/polunlin/workspace/A-deep-understanding-of-deep-learning/1.math/6.DUDL_math_entropy.ipynb#ch0000019?line=5'>6</a> q_tensor = torch.Tensor(q)
#       <a href='vscode-notebook-cell:/Users/polunlin/workspace/A-deep-understanding-of-deep-learning/1.math/6.DUDL_math_entropy.ipynb#ch0000019?line=6'>7</a> p_tensor = torch.Tensor(p)
# ----> <a href='vscode-notebook-cell:/Users/polunlin/workspace/A-deep-understanding-of-deep-learning/1.math/6.DUDL_math_entropy.ipynb#ch0000019?line=8'>9</a> F.binary_cross_entropy(p,q)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch_env/lib/python3.8/site-packages/torch/nn/functional.py:3055, in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch_env/lib/python3.8/site-packages/torch/nn/functional.py?line=3052'>3053</a> else:
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch_env/lib/python3.8/site-packages/torch/nn/functional.py?line=3053'>3054</a>     reduction_enum = _Reduction.get_enum(reduction)
# -> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch_env/lib/python3.8/site-packages/torch/nn/functional.py?line=3054'>3055</a> if target.size() != input.size():
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch_env/lib/python3.8/site-packages/torch/nn/functional.py?line=3055'>3056</a>     raise ValueError(
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch_env/lib/python3.8/site-packages/torch/nn/functional.py?line=3056'>3057</a>         "Using a target size ({}) that is different to the input size ({}) is deprecated. "
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch_env/lib/python3.8/site-packages/torch/nn/functional.py?line=3057'>3058</a>         "Please ensure they have the same size.".format(target.size(), input.size())
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch_env/lib/python3.8/site-packages/torch/nn/functional.py?line=3058'>3059</a>     )
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch_env/lib/python3.8/site-packages/torch/nn/functional.py?line=3060'>3061</a> if weight is not None:
#
# AttributeError: 'list' object has no attribute 'size'
