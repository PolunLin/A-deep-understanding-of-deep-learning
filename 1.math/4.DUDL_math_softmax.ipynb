# %% [markdown]
# # COURSE: A deep understanding of deep learning
# ## SECTION: Math prerequisites
# ### LECTURE: Softmax
# #### TEACHER: Mike X Cohen, sincxpress.com
# ##### COURSE URL: udemy.com/course/dudl/?couponCode=202204

# %%
# import libraries
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
# "manually" in numpy

# the list of numbers
z = [1,2,3]

# compute the softmax result
num = np.exp(z)
print(num)
den = np.sum( np.exp(z) )
print(den)
sigma = num / den

print(sigma)
print(np.sum(sigma))
# Out:
# [ 2.71828183  7.3890561  20.08553692]
# 30.19287485057736
# [0.09003057 0.24472847 0.66524096]
# 1.0

# %%
# repeat with some random integers
z = np.random.randint(-5,high=15,size=25)
print(z)

# compute the softmax result
num = np.exp(z)
den = np.sum( num )
sigma = num / den

# compare
plt.plot(z,sigma,'ko')
plt.xlabel('Original number (z)')
plt.ylabel('Softmaxified $\sigma$')
plt.yscale('log')
plt.title('$\sum\sigma$ = %g' %np.sum(sigma))
plt.show()
# Out:
# [-4  3 -1 13 -2  8  4 12 14  2  4 -5 -4 10 10  5  8 12  7 -3  4 -3 -2  3
#  -5]

# %% [markdown]
# # Using pytorch

# %%
# slightly more involved using torch.nn

# create an instance of the softmax activation class
softfun = nn.Softmax(dim=0)

# then apply the data to that function
sigmaT = softfun( torch.Tensor(z) )

# now we get the results
print(sigmaT)
# Out:
# tensor([9.0582e-09, 9.9335e-06, 1.8194e-07, 2.1880e-01, 6.6931e-08, 1.4743e-03,
#         2.7002e-05, 8.0492e-02, 5.9476e-01, 3.6543e-06, 2.7002e-05, 3.3323e-09,
#         9.0582e-09, 1.0893e-02, 1.0893e-02, 7.3399e-05, 1.4743e-03, 8.0492e-02,
#         5.4235e-04, 2.4623e-08, 2.7002e-05, 2.4623e-08, 6.6931e-08, 9.9335e-06,
#         3.3323e-09])

# %%
# show that they are the same
plt.plot(sigma,sigmaT,'ko')
plt.xlabel('"Manual" softmax')
plt.ylabel('Pytorch nn.Softmax')
plt.title(f'The two methods correlate at r={np.corrcoef(sigma,sigmaT)[0,1]}')
plt.show()
